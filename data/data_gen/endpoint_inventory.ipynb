# %%
# Cell 1: Setup and Paths
# Defines paths to ToolBench data and WS-DREAM QoS matrices. Also sets the output directory.
from pathlib import Path
import json, re, random
import pandas as pd
import numpy as np

TOOLBENCH_ROOT = Path("/Users/ishwaryapns/Documents/Thesis/MAOF/data/raw/toolbench/data/toolenv/tools")
WSD_RT = Path("../raw/wsdream/dataset1/rtMatrix.txt")
WSD_TP = Path("../raw/wsdream/dataset1/tpMatrix.txt")

OUT_DIR = Path("../processed/api_catalog_sample_balanced")
OUT_DIR.mkdir(parents=True, exist_ok=True)

NO_QOS_OUT = OUT_DIR / "api_repo.no_qos.jsonl"
WITH_QOS_OUT = OUT_DIR / "api_repo.with_qos.jsonl"
BALANCED_COUNTS = OUT_DIR / "api_repo.balanced_counts.csv"

random.seed(42)
print("ToolBench root:", TOOLBENCH_ROOT.resolve())
print("Output dir:", OUT_DIR.resolve())

# %%
# Cell 2: Helper Functions and QoS Computation
# Contains reusable functions to read files, parse JSON, extract endpoints, and compute QoS metrics.

def read_matrix(path: Path) -> pd.DataFrame:
    return pd.read_csv(path, header=None, sep=None, engine="python")

def slug(text: str) -> str:
    s = re.sub(r"[^a-zA-Z0-9]+", "_", (text or "").strip().lower()).strip("_")
    return s[:64] if s else "x"

def safe_get(d, key, default=None):
    return d.get(key, default) if isinstance(d, dict) else default

def yield_endpoints_from_tool(tool_obj: dict, tool_base: str, category: str, file_name: str):
    api_list = safe_get(tool_obj, "api_list", [])
    if not isinstance(api_list, list): return
    for ep in api_list:
        if not isinstance(ep, dict): continue
        name = safe_get(ep, "name") or ""
        url = safe_get(ep, "url") or ""
        method = safe_get(ep, "method") or ""
        desc = safe_get(ep, "description") or ""
        ep_id = f"{tool_base}_{slug(name) or 'endpoint'}"
        yield {
            "api_id": ep_id,
            "category": category,
            "name": name,
            "description": desc,
            "method": method,
            "url": url,
            "_file": file_name,
            "_tool": tool_base,
        }

def iter_endpoints_any_json(json_path: Path, category: str):
    try:
        data = json.loads(json_path.read_text())
    except Exception:
        return
    file_stem = json_path.stem
    tool_base_default = slug(file_stem)
    if isinstance(data, dict) and isinstance(data.get("api_list"), list):
        yield from yield_endpoints_from_tool(data, tool_base_default, category, json_path.name)
    elif isinstance(data, dict) and isinstance(data.get("tools"), list):
        for t in data["tools"]:
            if isinstance(t, dict):
                tool_base = safe_get(t, "standardized_name") or safe_get(t, "name") or tool_base_default
                yield from yield_endpoints_from_tool(t, slug(tool_base), category, json_path.name)
    elif isinstance(data, dict) and isinstance(data.get("endpoints"), list):
        tool_like = {
            "api_list": data["endpoints"],
            "standardized_name": safe_get(data, "standardized_name") or tool_base_default
        }
        yield from yield_endpoints_from_tool(tool_like, slug(tool_like["standardized_name"]), category, json_path.name)
    elif isinstance(data, list):
        for idx, item in enumerate(data):
            if isinstance(item, dict) and isinstance(item.get("api_list"), list):
                tool_base = safe_get(item, "standardized_name") or safe_get(item, "name") or f"{tool_base_default}_{idx}"
                yield from yield_endpoints_from_tool(item, slug(tool_base), category, json_path.name)

def compute_qos_per_column(rt_col: pd.Series, tp_col: pd.Series) -> dict:
    rt_valid = rt_col.replace(-1, np.nan).dropna()
    tp_valid = tp_col.replace(-1, np.nan).dropna()
    availability = len(rt_valid) / len(rt_col) if len(rt_col) > 0 else 0.0
    return {
        "rt_ms": float(np.median(rt_valid)) if not rt_valid.empty else None,
        "tp_rps": float(np.median(tp_valid)) if not tp_valid.empty else None,
        "availability": round(availability, 4),
        "valid_qos": not (rt_valid.empty or tp_valid.empty)
    }

# %%
all_endpoints = []
category_dirs = sorted([p for p in TOOLBENCH_ROOT.iterdir() if p.is_dir()])

for cat_dir in category_dirs:
    category = cat_dir.name
    for jf in sorted(cat_dir.glob("*.json")):
        for ep in iter_endpoints_any_json(jf, category):
            all_endpoints.append(ep)

print(f"Total endpoints collected: {len(all_endpoints)}")

seen = {}
unique_endpoints = []
for ep in all_endpoints:
    api_id = ep["api_id"]
    if api_id not in seen:
        seen[api_id] = 1
        unique_endpoints.append(ep)
    else:
        seen[api_id] += 1
        new_id = f"{api_id}-{seen[api_id]}"
        ep = {**ep, "api_id": new_id}
        unique_endpoints.append(ep)

print(f"Unique endpoints after de-duplication: {len(unique_endpoints)}")

# %%
from collections import defaultdict

# Group endpoints by category
cat_to_eps = defaultdict(list)
for ep in unique_endpoints:
    cat_to_eps[ep["category"]].append(ep)

# Count API quotas
category_quota = {}
fallback_categories = []
target_total = 5825
category_count = len(cat_to_eps)

# First, assign max 118 quota to every category
target_per_cat = target_total // category_count

# Track categories with fewer endpoints than quota
for cat, eps in cat_to_eps.items():
    if len(eps) < target_per_cat:
        category_quota[cat] = len(eps)
        fallback_categories.append(cat)
    else:
        category_quota[cat] = target_per_cat

# Compute remaining quota to redistribute
allocated = sum(category_quota.values())
remaining_quota = target_total - allocated
remaining_cats = [cat for cat in cat_to_eps if cat not in fallback_categories]

# Redistribute leftover quota evenly to remaining categories
for cat in remaining_cats:
    if remaining_quota <= 0:
        break
    category_quota[cat] += 1
    remaining_quota -= 1

# Final balanced endpoints list
balanced_endpoints = []
per_category_counts = []

for cat, eps in cat_to_eps.items():
    random.shuffle(eps)
    selected_eps = eps[:category_quota[cat]]
    balanced_endpoints.extend(selected_eps)
    per_category_counts.append({"category": cat, "selected": len(selected_eps)})

print(f"Total balanced endpoints: {len(balanced_endpoints)}")

# %%
df = pd.DataFrame(unique_endpoints)
quota = 5825
per_cat_quota = quota // df["category"].nunique()

sampled = []
counts = []
for cat, group in df.groupby("category"):
    if len(group) <= per_cat_quota:
        sampled_cat = group.copy()
    else:
        sampled_cat = group.sample(per_cat_quota, random_state=42)
    sampled.append(sampled_cat)
    counts.append({"category": cat, "selected": len(sampled_cat)})

balanced_df = pd.concat(sampled).reset_index(drop=True)
pd.DataFrame(counts).to_csv(BALANCED_COUNTS, index=False)

print(f"Saved balanced category counts -> {BALANCED_COUNTS.name}")
print(pd.DataFrame(counts).head())

# %%
rt_df = read_matrix(WSD_RT)
tp_df = read_matrix(WSD_TP)

if rt_df.shape != tp_df.shape:
    raise ValueError(f"RT/TP shape mismatch: {rt_df.shape} vs {tp_df.shape}")

n_users, n_cols = rt_df.shape
print(f"WS-DREAM matrix: {n_users} users × {n_cols} API columns")

# %%
col_indices = list(range(n_cols))
random.shuffle(col_indices)

with NO_QOS_OUT.open("w", encoding="utf-8") as no_qos_f, \
     WITH_QOS_OUT.open("w", encoding="utf-8") as with_qos_f:

    for i, ep in enumerate(balanced_df.to_dict(orient="records")):
        base = ep  # Keeping everything including _file for future use
        no_qos_f.write(json.dumps(base, ensure_ascii=False) + "\n")

        c = col_indices[i % n_cols]
        qos = compute_qos_per_column(rt_df[c], tp_df[c])
        with_qos_f.write(json.dumps({**base, "qos": qos}, ensure_ascii=False) + "\n")

print(f"Wrote: {NO_QOS_OUT.name}  ({len(balanced_df)} entries)")
print(f"Wrote: {WITH_QOS_OUT.name} ({len(balanced_df)} entries)")

# %%
from pathlib import Path
import json

# -------- CONFIG --------

# %%
from pathlib import Path
print("cwd =", Path.cwd())
# Out:
# cwd = /Users/ishwaryapns/Documents/Thesis/MAOF_3/MAOF/data/data_gen

# %%
from pathlib import Path
import json
import time

# ---------------- CONFIG ----------------
PROJECT_ROOT = Path("/Users/ishwaryapns/Documents/Thesis/MAOF_3/MAOF")
TOOLBENCH_ROOT = Path("/Users/ishwaryapns/Documents/Thesis/ToolBench/data/toolenv/tools")

CATALOG_DIR = PROJECT_ROOT / "data/processed/api_catalog_sample_balanced"
WITH_QOS_CATALOG = CATALOG_DIR / "api_repo.with_qos.jsonl"
NO_QOS_CATALOG = CATALOG_DIR / "api_repo.no_qos.jsonl"

WITH_QOS_OUT = CATALOG_DIR / "api_repo.with_qos.tooldesc.jsonl"
NO_QOS_OUT = CATALOG_DIR / "api_repo.no_qos.tooldesc.jsonl"

MAX_ROWS = None
PROGRESS_EVERY = 500

# ---------------- HELPERS ----------------
_tool_file_cache = {}

def load_tool_file(category: str, file_name: str):
    if not category or not file_name:
        return None

    key = (category, file_name)
    if key in _tool_file_cache:
        return _tool_file_cache[key]

    path = TOOLBENCH_ROOT / category / file_name
    if not path.exists():
        _tool_file_cache[key] = None
        return None

    try:
        with open(path, "r", encoding="utf-8") as f:
            data = json.load(f)
        _tool_file_cache[key] = data
        return data
    except Exception as e:
        print(f"[WARN] Failed reading tool file: {path} | {e}", flush=True)
        _tool_file_cache[key] = None
        return None


def clean_text(x, max_len=300):
    if x is None:
        return ""
    x = str(x).strip()
    x = " ".join(x.split())
    return x[:max_len]


def enrich_record(rec: dict):
    category = rec.get("category")
    file_name = rec.get("_file")

    tool_json = load_tool_file(category, file_name)

    tool_name = ""
    tool_description = ""

    if isinstance(tool_json, dict):
        tool_name = (
            tool_json.get("tool_name")
            or tool_json.get("name")
            or tool_json.get("title")
            or ""
        )
        tool_description = tool_json.get("tool_description") or ""

    rec["tool_name"] = clean_text(tool_name, max_len=120)
    rec["tool_description"] = clean_text(tool_description, max_len=300)
    return rec


def count_lines(path: Path):
    with open(path, "r", encoding="utf-8") as f:
        return sum(1 for _ in f)


def process_catalog(in_path: Path, out_path: Path):
    start = time.time()

    print(f"\n[START] Processing: {in_path}", flush=True)
    print(f"[INFO] Output file: {out_path}", flush=True)

    if not in_path.exists():
        print(f"[ERROR] Input file does not exist: {in_path}", flush=True)
        return

    total_lines = count_lines(in_path)
    print(f"[INFO] Input rows detected: {total_lines}", flush=True)

    out_path.parent.mkdir(parents=True, exist_ok=True)

    total = 0
    enriched = 0
    missing_tool_json = 0
    missing_examples = []

    with open(in_path, "r", encoding="utf-8") as fin, open(out_path, "w", encoding="utf-8") as fout:
        for idx, line in enumerate(fin, start=1):
            if MAX_ROWS is not None and idx > MAX_ROWS:
                break

            line = line.strip()
            if not line:
                continue

            try:
                rec = json.loads(line)
            except Exception as e:
                print(f"[WARN] Bad JSON at row {idx}: {e}", flush=True)
                continue

            total += 1

            category = rec.get("category")
            file_name = rec.get("_file")

            tool_json = load_tool_file(category, file_name)
            if tool_json is None:
                missing_tool_json += 1
                if len(missing_examples) < 10:
                    missing_examples.append((idx, category, file_name))

            rec = enrich_record(rec)

            if rec.get("tool_name") or rec.get("tool_description"):
                enriched += 1

            fout.write(json.dumps(rec, ensure_ascii=False) + "\n")

            if total % PROGRESS_EVERY == 0:
                elapsed = time.time() - start
                print(
                    f"[PROGRESS] rows={total} enriched={enriched} missing_tool_json={missing_tool_json} elapsed={elapsed:.1f}s",
                    flush=True
                )

    elapsed = time.time() - start

    print(f"\n[DONE] Processed: {in_path.name}", flush=True)
    print(f"[DONE] Output: {out_path.name}", flush=True)
    print(f"[DONE] Total rows written: {total}", flush=True)
    print(f"[DONE] Enriched rows: {enriched}", flush=True)
    print(f"[DONE] Missing tool json: {missing_tool_json}", flush=True)
    print(f"[DONE] Cache size: {len(_tool_file_cache)}", flush=True)
    print(f"[DONE] Time taken: {elapsed:.1f}s", flush=True)

    if missing_examples:
        print("[INFO] Sample missing tool-json rows:", flush=True)
        for ex in missing_examples:
            print(f"  row={ex[0]} category={ex[1]!r} _file={ex[2]!r}", flush=True)


# ---------------- PRECHECK ----------------
print("[CHECK] PROJECT_ROOT =", PROJECT_ROOT, flush=True)
print("[CHECK] TOOLBENCH_ROOT =", TOOLBENCH_ROOT, flush=True)
print("[CHECK] TOOLBENCH_ROOT exists =", TOOLBENCH_ROOT.exists(), flush=True)
print("[CHECK] WITH_QOS_CATALOG exists =", WITH_QOS_CATALOG.exists(), flush=True)
print("[CHECK] NO_QOS_CATALOG exists =", NO_QOS_CATALOG.exists(), flush=True)

# ---------------- RUN ----------------
process_catalog(WITH_QOS_CATALOG, WITH_QOS_OUT)
process_catalog(NO_QOS_CATALOG, NO_QOS_OUT)

print("\nAll done. Existing QoS values were preserved exactly.", flush=True)
# Out:
# [CHECK] PROJECT_ROOT = /Users/ishwaryapns/Documents/Thesis/MAOF_3/MAOF
# [CHECK] TOOLBENCH_ROOT = /Users/ishwaryapns/Documents/Thesis/ToolBench/data/toolenv/tools
# [CHECK] TOOLBENCH_ROOT exists = True
# [CHECK] WITH_QOS_CATALOG exists = True
# [CHECK] NO_QOS_CATALOG exists = True
#
# [START] Processing: /Users/ishwaryapns/Documents/Thesis/MAOF_3/MAOF/data/processed/api_catalog_sample_balanced/api_repo.with_qos.jsonl
# [INFO] Output file: /Users/ishwaryapns/Documents/Thesis/MAOF_3/MAOF/data/processed/api_catalog_sample_balanced/api_repo.with_qos.tooldesc.jsonl
# [INFO] Input rows detected: 5559
# [PROGRESS] rows=500 enriched=500 missing_tool_json=0 elapsed=0.2s
# [PROGRESS] rows=1000 enriched=1000 missing_tool_json=0 elapsed=0.4s
# [PROGRESS] rows=1500 enriched=1500 missing_tool_json=0 elapsed=0.5s
# [PROGRESS] rows=2000 enriched=2000 missing_tool_json=0 elapsed=3.4s
# [PROGRESS] rows=2500 enriched=2500 missing_tool_json=0 elapsed=3.9s
# [PROGRESS] rows=3000 enriched=3000 missing_tool_json=0 elapsed=4.6s
# [PROGRESS] rows=3500 enriched=3500 missing_tool_json=0 elapsed=4.9s
# [PROGRESS] rows=4000 enriched=4000 missing_tool_json=0 elapsed=5.0s
# [PROGRESS] rows=4500 enriched=4500 missing_tool_json=0 elapsed=7.3s
# [PROGRESS] rows=5000 enriched=5000 missing_tool_json=0 elapsed=7.5s
# [PROGRESS] rows=5500 enriched=5500 missing_tool_json=0 elapsed=7.6s
#
# [DONE] Processed: api_repo.with_qos.jsonl
# [DONE] Output: api_repo.with_qos.tooldesc.jsonl
# [DONE] Total rows written: 5559
# [DONE] Enriched rows: 5559
# [DONE] Missing tool json: 0
# [DONE] Cache size: 2763
# [DONE] Time taken: 7.7s
#
# [START] Processing: /Users/ishwaryapns/Documents/Thesis/MAOF_3/MAOF/data/processed/api_catalog_sample_balanced/api_repo.no_qos.jsonl
# [INFO] Output file: /Users/ishwaryapns/Documents/Thesis/MAOF_3/MAOF/data/processed/api_catalog_sample_balanced/api_repo.no_qos.tooldesc.jsonl
# [INFO] Input rows detected: 5559
# [PROGRESS] rows=500 enriched=500 missing_tool_json=0 elapsed=0.0s
# [PROGRESS] rows=1000 enriched=1000 missing_tool_json=0 elapsed=0.0s
# [PROGRESS] rows=1500 enriched=1500 missing_tool_json=0 elapsed=0.0s
# [PROGRESS] rows=2000 enriched=2000 missing_tool_json=0 elapsed=0.0s
# [PROGRESS] rows=2500 enriched=2500 missing_tool_json=0 elapsed=0.0s
# [PROGRESS] rows=3000 enriched=3000 missing_tool_json=0 elapsed=0.1s
# [PROGRESS] rows=3500 enriched=3500 missing_tool_json=0 elapsed=0.1s
# [PROGRESS] rows=4000 enriched=4000 missing_tool_json=0 elapsed=0.1s
# [PROGRESS] rows=4500 enriched=4500 missing_tool_json=0 elapsed=0.1s
# [PROGRESS] rows=5000 enriched=5000 missing_tool_json=0 elapsed=0.1s
# [PROGRESS] rows=5500 enriched=5500 missing_tool_json=0 elapsed=0.1s
#
# [DONE] Processed: api_repo.no_qos.jsonl
# [DONE] Output: api_repo.no_qos.tooldesc.jsonl
# [DONE] Total rows written: 5559
# [DONE] Enriched rows: 5559
# [DONE] Missing tool json: 0
# [DONE] Cache size: 2763
# [DONE] Time taken: 0.1s
#
# All done. Existing QoS values were preserved exactly.
